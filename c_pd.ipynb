# %%
# Speed of Numpy
 
import numpy as np
import time
from utils import dur
 
prices = [15,14,41,32] * 1_000_000
 
np_prices = np.array(prices)

# %%
print(len(prices))
print(len(np_prices))
# Out:
# 4000000
# 4000000

# %%
start = time.time()
mult_ls = [p*1.05 for p in prices]
print(f"Duration to update List: {dur(start)}")
 
start = time.time()
mult_np = np_prices * 1.05
print(f"Duration to update NpArray: {dur(start)}")
# Out:
# Duration to update List: 0.3177940845489502
# Duration to update NpArray: 0.0071942806243896484

# %%
import pandas as pd
import matplotlib.pyplot as plt
 
print(pd.__version__)
 
tickers = pd.Series(["AAPL", "GOOG", "MSFT"])
price_list = [150,180,140]
prices = pd.Series(price_list)
 
print(tickers)
print(prices)
# Out:
# 2.2.2
# 0    AAPL
# 1    GOOG
# 2    MSFT
# dtype: object
# 0    150
# 1    180
# 2    140
# dtype: int64

# %%
df = pd.DataFrame({
    "Symbol": tickers,
    "Price": prices
})
 
df
# Out:
#   Symbol  Price
# 0   AAPL    150
# 1   GOOG    180
# 2   MSFT    140
